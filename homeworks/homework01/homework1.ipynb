# %% [markdown]
# # Homework 1: Getting Set Up (Docker & Git)

# %% [markdown]
# <b>Assigned (Fall 2024)</b>: 8/28/24<br>
# <b>Due:</b> <font color="red"><b>9/4/24 at 11:59pm</b></font><p>
#
# <b>Points:</b> 500 points towards the Final Grade.
#
# Completion of all steps by the deadline will result in an automatic 500 points.
#
# ><b>Note</b>: This homework assignment takes several steps, and is the bulk of your budgeted time outside of class for the first week. (The rest is the required readings). So be sure to <b>start early</b>, and do not put this off until the last minute.
#
# You are <b>encouraged</b> to work together with classmates to help each other with the set up and ask questions on the course Slack. But <b>each student must create their own accounts</b>.

# %% [markdown]
# ## Introduction
#
# Welcome to your first assignment! The main focus will be to get you set up with the tools we’ll be using throughout CSE 20133/20232, and give you an intuitive understanding of each one.
#
# The main tools we’ll be using are <b>Docker</b>, a convenient way to manage virtual environments as “containers”, and <b>Git</b>, the most prominent version control software.
#
# |Tool|Use|
# |:---|:---|
# |<b>Docker</b>|Software environment virtualization|
# |<b>Git</b>|Version control software|
# |<b>GitHub</b>|Online code storage and version control|

# %% [markdown]
# ## Why are we using these tools?
#
# <ul>
#     <li><b>You’ll be able to develop locally.</b> With virtualization, we can specify a standard development environment on any machine, so your code will work no matter where it’s run. (You won’t need to log into the CSE department machines to write, test, or hand in your code!)</li>
# <li><b>Version control is awesome.</b> All changes to your code are tracked and can be reverted, making testing and debugging significantly more bearable. Your changes are also semi-automatically merged with other people’s, making collaboration easy. CSE 20133/20232 has no partner assignments, but version control will be useful for other courses that do.</li>
# <li><b>It’s how it’s done in the industry.</b> Most companies use some form of version-control in order to better manage projects and collaboration, and use machine virtualization for easier deployment and testing.</li>
# </ul>

# %% [markdown]
# ## Development Environment Setup
#
# Your computer is probably running Mac OS X, Windows, or Linux. These different <i>operating systems</i> all come with different libraries and preinstalled software. A <a href = "https://www.youtube.com/watch?v=yIVXjl4SwVo" target="_blank">Virtual Machine</a> (VM) can establish the same software environment for everyone.<p>
#
# Software inside a VM believes it is running on a physical computer, even though it is running within an OS within another computer. Achieving this level of virtualization has costs, including the cost of emulating the underlying hardware.<p>
#
# In the CSE 20133/20232 course, we will use a <b>container</b>, a technology that emulates an OS without the full overhead of a VM. The container runs a Linux-based operating system, <b>Ubuntu</b>. Our grading server also runs a Linux-based OS, so if your code works in the container, it <i>will</i> work on the grading server.<p>
#
# ><b>Optional Reading</b> - <i>Virtual machines vs. containers?</i> We will talk about this in the OS section of the course. But if you’re curious, <a href = "https://www.backblaze.com/blog/vm-vs-containers/" target="_blank">here</a> is a more detailed walk-through of the differences between a Virtual Machine and a container.

# %% [markdown]
# ## Docker
#
# <a href = "https://www.docker.com/" target="_blank">Docker</a> is one of the most popular container solutions and widely used in industry. In CSE 20133/20232, we use Docker because it lets you run a course container on Windows, macOS, or Linux.

# %% [markdown]
# ### Step 1: Download and install Docker.
#
# If you have a Windows or Mac, you may download Docker <a href = "https://www.docker.com/products/docker-desktop/" target="_blank">here</a>. On Linux machines, follow the instructions <a href = "https://docs.docker.com/engine/install/ubuntu/" target="_blank">here</a>.
#
# After downloading Docker, follow Docker’s instructions to install it on your OS. Accept if Docker asks for privileged access. Be sure to save everything you are working on, because you will need to close and restart your computer.
#
# On Windows or macOS, open the <i>Docker Desktop</i> application after it has been installed. You may see a message similar to “Docker Desktop is Starting…”. Once this message goes away, your Docker has started successfully!
#
# >If you are asked for log-in information, you can "Skip" this step. We have configured the assignments to ensure you only need the free version of Docker Desktop.
#
# Verify Docker is installed by executing the following command in a terminal (Windows - Command Prompt, MacOS - Terminal)
#
# ><code>docker --version</code>
#
# Here is an example from my installation on Windows, where I opened <b>Command Prompt</b>:
#
# <img src ="https://github.com/mmorri22/cse20133/blob/main/homeworks/homework01/homework0-1.png?raw=true">
#
# After installing Docker, a Docker process (the Docker daemon) will run in the background. Run the following command to verify:
#
# ><code>docker info</code>
#
# This should print some information about your Docker installation.
#
# <b>Note:</b> If you see the following error:
#
# ><code>ERROR: Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?</code>
#
# it means Docker hasn’t started running yet. On Windows or macOS, ensure your Docker Desktop is running. On Linux, try the command <code>sudo systemctl docker restart</code> in a terminal.
#
# If you’re running into other problems while setting up Docker, check out our <a href = "https://github.com/mmorri22/cse20133/blob/main/assets/docker_debugging.ipynb">Docker debugging guide</a>!
#
# <b>For Windows users, go to Step 1.1. For Mac and Linux users, go to Step 1.2</b>

# %% [markdown]
# ### Step 1.1: Windows Users Only: Windows Subsystem for Linux
#
# To run the following steps in this lab, you will need to set up Windows Subsystem for Linux (WSL). WSL should already be enabled after you install Docker, but you may still need to install a Linux distribution. To establish if you have this setup, perform the following steps:
#
# > <b>Quick Note:</b> In industry, Linux distributions are commonly known as <i>distros</i>.
#
# <b>1.</b><b>Do I have a Linux distro installed?</b>
#     <ul>
#         <li>Run <code>wsl --update</code> to ensure you have the most recent version</li>
#         <li>Run <code>wsl -l -v</code> in the Command Prompt. If there is only “Docker Desktop” and “Docker Desktop Data”, you do not have a Linux distro installed. Proceed to step 2.</li>
#         <li>Otherwise, you have a Linux distro installed. Proceed to step 3.</li>
#         <li><b>Note:</b>Docker Desktop installs two special-purpose internal Linux distros docker-desktop and docker-desktop-data. The first (docker-desktop) is used to run the Docker engine (dockerd) while the second (docker-desktop-data) stores containers and images.</li>
#     </ul>
#
# <b>2.</b><b>Install a Linux Distribution.</b>
#     <ul>
#         <li>Run <code>wsl --set-default-version 2</code> to ensure Ubuntu will be installed under WSL 2.</li>
#             <li>Install “Ubuntu 20.04” from Microsoft Store. (link <a href = "https://apps.microsoft.com/store/detail/ubuntu-20046-lts/9MTTCL66CPXJ?hl=en-us&gl=us">Here</a>)</li>
#         <li>Click “Open” after Ubuntu is downloaded. A terminal will open and guide you through the installation process. (For the username/password, students have found using their Notre Dame netID and password maintains the simplicity of remembering their information.)</li>
#     </ul>
#
# <b>3.</b><b>Ensure your Linux Distribution runs on WSL 2.</b>
#     <ul>
#         <li>Run <code>wsl -l -v</code> in the Command Prompt</li>
#         <li>If the <code>Ubuntu</code> distribution is running on Version 2, proceed to Step 4.</li>
#         <li>Otherwise, run <code>wsl --set-version < distro name > 2</code> to update your distro to use WSL 2. For example, my version is Ubuntu-20.04, so the command would be <code>wsl --set-version Ubuntu-20.04 2</code>.</li>
#     </ul>
#
# <b>4.</b><b>Set your default Linux distro</b>
#     <ul>
#         <li>Run <code>wsl --setdefault < distro-name > </code> to configure your default Linux distro. <distro-name> should be “Ubuntu-20.04” if you installed using step 2.</li>
#             <li>Example: <code>wsl --setdefault Ubuntu-20.04</code></li>
#             <li>The response should be <code>The operation was completed successfully</code>
#     </ul>
#
# Enter <code>wsl</code> in your Command Prompt, and you’ll enter into your WSL! For the rest of the Lab, run commands within your WSL Linux environment, unless otherwise specified.
#
# You will also need to connect Docker with WSL. To do so, open your Docker Desktop’s settings (on its top right corner), click “Resources”, “WSL integration”, then enable integration with your Linux distribution. The <code>Ubuntu-20.04</code> should be listed and not selected. Select <code>Ubuntu-20.04</code>. Then, click “Apply and Restart”.
#
# ### Step 1.2 - Restart your Machine
#
# At this point, close both the Docker and the Command Prompt/Terminal. We are doing this so you can get practice with starting Docker and Command Prompt/Terminal in Step 2. Furthermore, it will ensure that the Docker is able to connect to the Internet once you restart. Restart your computer.

# %% [markdown]
# ## Step 2 - Set up the CSE 20133/20232 Docker Environment
#
# In Docker, an environment is defined as a <b>Docker image</b>. An image specifies the operating system environment that a container provides. An image can also contain additional software dependencies and configurations. These instructions are specified in a file, the so-called <b>Dockerfile</b>.
#
# If you are using Windows, go to Step 2.1. For Mac users, go to Step 2.2.
#
# ### Step 2.1 - (Windows Users Only) Opening an Installed Docker
#
# First, open your Docker Desktop, as you did previously.
#
# Next, open your Command Prompt, as you did previously.
#
# Run the command in the Command Prompt (not in Docker Desktop) to verify the Docker version install
#
#     docker --version
#
# Next, run <code>wsl -l -v</code> in the Command Prompt. You should see the Ubuntu, docker-desktop, and docker-desktop-data.
#
# Run <code>wsl</code> to start the Windows Subsystem for Linux.
#
# To test if the system is connected to the internet, run the command <code>ping google.com -c 8</code>. If you see 8 successful tests, you have successfully connected to the internet within the Ubuntu container. (This will be essential as we install programs in the container.)
#
# <b>Go to step 2.3</b>
#
# ### Step 2.2 (Mac Users Only) - Install Apple development tools
#
# If you’re running on macOS, you will need to install a set of Apple-recommended command-line tools via the following command in the Terminal (not in Docker Desktop):
#
#     xcode-select --install
#
# This ensures that your computer has installed <code>git</code>, a program we’ll use below. Alternatively, you may also download and install git directly, following instructions <a href = "https://git-scm.com/download/mac">here</a>.
#
# Once installed, follow the steps in
#
# ### Step 2.3 - Setting up the Development Environment
#
# These steps assume you have successfully opened Docker Desktop. If you are running on a Mac, it is assumed you successfully installed XCode and Git in the Terminal. If you are running on a Windows machine, you are successfully running <code>wsl</code> in the Command Prompt.
#
# <b>1.</b> Enter the following command in the <i>Command Prompt/Terminal</i> (not in Docker Desktop) to download our development environment to the new subdirectory <code>cse20133</code>.
#
# ><code>git clone https://github.com/mmorri22/cse20133-docker.git cse20133</code>
#
# This command clones a GitHub repository onto your computer; we will explain the details of Git and cloning later in this lab.
#
# <b>4.</b> In order to <i>change directorites</i> into the new folder, you will run the <code>cd</code> command.
#
# ><code>cd cse20133</code>
#
# <b>5.</b> Inside this folder, perform the following commands:
#
# ><code>cd docker</code><br>
# ><code>./cse20133-build-docker</code>
#
# <code>./cse20133-build-docker</code> builds your docker image, which may take a while. It’s perfectly normal for this script to run for up to 15 minutes. The <code>./</code> in front of the script name is required to run executables in the Linux environment. (You will get plenty of practice.)
#
# > <b>For macOS/Linux users</b>, if you encountered the error message: `permission denied errores: <filename>` when executing a file, run this command to add execution permission to the file: `chmod +x <filename>`.<br>
# > For this example, it will be <code>chmod +rx cse20133-build-docker</code>
#
# ### Step 2.4 - Creating and Entering the Container
#
# In this step, we will create the container. First, we will go <i>up</i> one level in the file hierarchy. You will get a lot more experience and familiarity with file hierarchies this semester. For now, think of it as going up and down a step. The previous command <code>cd docker</code> took you <i>down</i> one step. This next command will take you back <i>up</i> one step using <code>..</code>.
#
#     cd ..
#
# To verify you performed the step correctly, you can list all the files using the <code>ls</code> and <code>pwd</code> commands.
#
# ><code>pwd</code> means "Present Working Directory", which tells you where you are in the file hierarchy. It's like telling you what room you are in.
#
# If you are in the correct file location, it should look like this:
#
# <code>/mnt/c/Users/mmorri22/cse20133> ls</code><br>
# <code>README.md  cse20133-run-docker  <font color=#ADD8E6 style="background-color: green;">docker</font><br></code>
# <code>/mnt/c/Users/mmorri22/cse20133> pwd</code><br>
# <code><font color=#FF0000>/mnt/c/Users/mmorri22/cse20133</font></code><br>
#
# >The highlighted name <font color=#ADD8E6 style="background-color: green;">docker</font> indicates that is a <b>folders</b>. The <code>cd docker</code> command took you into the docker folder, and the <code>cd ..</code> command brought you back up into the <b>cse20133</b> folder.
#
# > In my example (Windows machine), the <code>/mnt/c/Users/mmorri22/cse20133</code> is the same as going into the File Explorer and entering <code>C:\Users\mmorri22\cse20133</code>
#
# Next, you will create the container by running the run docker script:
#
#     ./cse20133-run-docker
#
# ><b>Note:</b> If you are using a Mac, and you needed to run <code>chmod</code> before, you will likely need to do it again here. That command will be <code>chmod +rx cse20133-run-docker</code>
#
# A successful instantiation of the container will look like this:
#
#     ./cse20133-run-docker
#     Starting a new container...
#     cse20133-user@eeaad3a9f255:~$
#
# You will also be able to verify a successful start by opening Docker Desktop, and selecting "Containers". It will appear similar to this image below:
#
# <img src ="https://github.com/mmorri22/cse20133/blob/main/homeworks/homework01/homework0-2.png?raw=true">
#
# In the Command Prompt / Terminal window, type the following commands:
#
#     touch demo.txt
#     ls
#
# The <code>touch</code> command creates a file named <code>demo.txt</code>, and <code>ls</code> lists the files. Now perform the following command:
#
#     ls -l
#
# This command shows several pieces of information about your file. Here is an example:
#
#     -rwxrwxrwx 1 cse20133-user cse20133-user 0 Aug 11 12:56 demo.txt
#
# We will learn about the importance of every single piece of information on this line. You can see that <code>Aug 11 12:56</code> means that is the date and time that the file <code>demo.txt</code> was last accessed. Also, the value <code>0</code> indicates that the file is <b>0 bytes</b>, an empty file.
#
# ### Step 2.5 - Closing and Opening the Container
#
# In this step, you will get practice with closing and opening the container. During the first few in-class coding opportunities and homework assignments, we will repeat these steps to help you gain familiarity
#
# <b>1.</b> Close the Command Prompt / Terminal by selecting the X in the corner.
#
# <b>2.</b> <i>Stop</i> the Virtual Machine. Click on the <code>cse20133-container</code> link under "Containers" in the Docker Desktop. Then, select the Blue Stop Box in the top right. This will <i>stop</i> the container, but not delete it.
#
# > <b>Note:</b> The reason you should <i>stop</i> the Virtual Machine is because VMs take up precious computing resouces and will make the rest of your device run slower. Computers in Electronic, Mechanical, and Aeronautical environments often have <i>extremely limited resources</i>.
#
# > During this course, never, ever, ever, ever, ever, ever select the red delete trash can. This will delete all your work and the containter. If you do, make sure you contact Professor Morrison immediately. One of the benefits of <b>git</b> is that you will have regular backups of your code.
#
# <b>3.</b> Close out of the Docker Desktop.
#
# ### Now we will practice starting the Container
#
# <b>1.</b> Re-open the Docker Desktop. Select <b>Containters</b>, and then select your Container.
#
# <b>2.</b> Select the Blue Triangle (Start) button. Now you have started the Container.
#
# <b>If you are a Windows User, and you had an issue, go to Step 2.6</b>
#
# <b>If you did not have any issues, you may go to Step 3 - Finding your Container and Files.</b>

# %% [markdown]
# ### Step 2.6 - Windows Users with Issues
#
# If you see errors along the lines of <code>bash: '\r': command not found</code> or <code>bash: /home/cs300-user/.bash_profile: line 5: syntax error: unexpected end of file</code> when you enter the container, you need to convert your files’ line endings (characters that delineate the end of a line) from Windows to UNIX (Linux) format.
#
# To do so, do the following:
#
# <ol>
# <li>Enter into WSL. You may do so by opening Ubuntu in the start menu or through the <code>wsl</code> command.</li>
# <li>Use cd to navigate to the folder where you just cloned the setup repository. If you cloned your setup repository to your <code>C:</code> drive, use <code>cd /mnt/c</code> to enter the <code>C:</code> drive from your WSL.</li>
# <li>Run <code>sudo apt-get update</code>, then install <code>dos2unix</code> with <code>sudo apt-get -y install dos2unix</code>.</li>
# <li>Run <code>dos2unix ./cse20133-run-docker</code> (you should only need to run this once).</li>
# <li>Next, run <code>./cse20133-run-docker</code>.</li>
# <li>If you see the next line begins with <code>cse20133-user@@9899143429a2:~$ ...</code>, you’re inside the container, hopefully without errors!</li>
# </ol>

# %% [markdown]
# ## Step 3 - Text Editors and IDEs
#
# What development environment or editor to use is a question that divides people and has led to countless hours being wasted on heated discussion, offline and online for decades. Some people prefer very simple editors that run in their terminal, while others prefer graphical integrated development environments (IDEs). For CSE 20133/20232, we don’t really care what you use – if it works for you, great!
#
# To make your life easier, however, you probably want to use an editor with syntax highlighting for <b>C</b> and <b>C++</b>, the main programming languages we’ll use in CSE 20133. When you edited demo.txt, there was very little to help you other than the text itself. If the code gets to hundreds of lines of code, dicphering the code becomes prohibitively difficuly. So we will install visual editors and IDEs to assist you in program development.
#
# > <b>Note 1:</b> These steps assume you have successfully installed Docker Desktop, and that your <code>cse20133-container</code> is running, just like in Step 2.5.
#
# > <b>Note 2:</b> A video where I replicate Steps 3.1-3.3 is provided if you would like clarity on the text directions.
#
# ### Step 3.1 - Download VSCode Insiders
#
# VSCode is a free IDE built by Microsoft, and has support for all major languages (including C and C++). It also comes with built-in Git integration. Runs on macOS, Linux, and Windows, as well as connection options to the class VM. It has very nice integration with our Docker container, and it’s nicely customizable with extensions.
#
# These steps will assume you are installing VSCode:
#
# <b>1.</b> Make sure your course container is running.
#
# <b>2.</b> Go to the <a href = "https://code.visualstudio.com/insiders/">VSCode Insiders</a> page and download VSCode on your own computer (not the course container). The website will detect your Operating System and recommend the appropriate version.
#
# <b>3.</b> Run the executable for VSCode.
#
# <b>4.</b> Open VSCode, and on the left, select the icon for Extensions
# <img src = "https://i.imgur.com/x7Nedgs.png">
#
# <b>5.</b> Search for and Install the “Docker”, “Dev Containers”, and “WSL” VSCode extensions via the extensions tab.
#
# <b>6.</b> Click the blue button in the bottom left of VSCode. At the top, select the pull-down choice “Attach to running container” and select your CSE 20133 course container. The installation will take a few moments.
# <img src = "https://microsoft.github.io/vscode-remote-release/images/remote-dev-status-bar.png">
#
# <b>7.</b> A new window will pop up with the container. On the left-hand side, select the arrow next to the CSE20133-USER container. This will open the entire folder for your container. You will see <code>demo.txt</code>. Double click the file.
#
# <b>8.</b> Make another edit to demo.txt using the IDE. You can save by either doing <b>File->Save</b> or use the <b>Ctrl-s</b> keyboard shortcut.
#
#
# ### Step 3.2 - Download and install vim
#
# <b>vim</b> is a classic, highly configurable editor that comes with many Linux distributions. It’s a multi-mode editor, meaning that you have to switch between modes (e.g., input, select, edit). It runs in the terminal, all functions are controlled by keystrokes and internal commands, and vim can be customized with plugins.
#
# > <b>Note:</b> Based on my experience, the overwhelming majority of students in this course will eventually pick the IDE over vim because of the improved usability. However, vim is a required concept for Electrical Engineers in future courses that require programming. So will will perform some tasks using vim in order for the EEs.
#
# ><b>Note:</b> When we install programs, we will use the Docker Desktop Terminal instead of the VSCode Terminal, because the installations are sometimes impermanent through VSCode. We will only use this tab for installing programs, as the VSCode terminal is more robust for programming.
#
# In the Docker Desktop, select the container, and then select the Terminal tab.
#
# Run the following two commands to update your environment and install vim. Also, if you receive a [y/n] prompt during the installation, say yes.
#
#     sudo apt-get update
#     sudo apt-get install vim
#
# > Respond to any prompt asking if you wish to continue with <code>Y</code>
#
# > Note that <code>sudo</code> means that you are running the code as the <i>administrator</i> in the container.
#
# To get your first experience with <code>vim</code>, you will modify your demo.txt file with an updated message.
#
# >I will type out the steps to update a file below. Since these can be a bit confusing to a new user, I will include a video where I perform the identical steps after the directions. If the steps are a bit confusing, watch the video to see how I do it.
#
# <b>1.</b> Type <code>vim demo.txt</code> to open the file in vim.
#
# <b>2.</b> Type the letter <code>i</code> in order to <b>insert</b> text into the file. You will see <code>-- INSERT --</code> at the bottom indicating you can make edits.
#
# <b>3.</b> Make edits through the terminal to modify the message.
#
# <b>4.</b> To stop editing, type <code>Esc</code> to stop the insertion. You will see the <code>-- INSERT --</code> disappear.
#
# <b>5.</b> Now we will begin the process of saving and quitting vim. First, hold the <b>Shift</b> button and then tap the <code>:</code> button, releasing Shift. You will see <code>:</code> and a flashing cursor at the bottom.
#
# <b>6.</b> Type <code>wq!</code> in the cursor and press Enter.
#
# <b>7.</b> You will now have closed vim and be back in the terminal. If you type <code>ls -l</code> again, you will be able to see the change in the size of the file.
#
# ### Step 3.3 - Practice Closing and Opening Docker and VS Code
#
# In this step, you will get practice closing and opening <b>Docker Desktop</b> and <b>VS Code</b>. Now that we have set up the primary programs you will need for the course, these steps will be the steps you perform to open your environment every time.
#
# <b>1.</b> Close VS Code using the X in the top right corner.
#
# <b>2.</b> In Docker Desktop, go to the Container, and then press the square button for stop. This step ensures your Docker doesn't consume computing resources while you are using it.
#
# Now, we will restart the Docker.
#
# <b>1.</b> Open Docker Desktop. Go to the cse20133-user Container you created. Press the Blue Triangle to start the Container.
#
# <b>2.</b> Open VSCode, and on the left, select the blue button in the bottom left of VSCode. At the top, select the pull-down choice “Attach to running container” and select your CSE 20133 course container. The installation will take a few moments.
# <img src = "https://microsoft.github.io/vscode-remote-release/images/remote-dev-status-bar.png">
# <b>3.</b> Open a folder. Click the "Open" button, the **home directory** will be loaded by default.
#
# And now you are back in the Coding Environment!
#
# > <b>Visualize It</b> - In this video, I perform the steps for opening the Docker Desktop, VS Code, and making changes using both vim and the text editor. Select the image below to view the video.
#
# [![](http://img.youtube.com/vi/muL1qvhzuyE/mqdefault.jpg)](https://www.youtube.com/watch?v=muL1qvhzuyE)

# %% [markdown]
# ## Step 4 - Finding your Container and Files
#
# In this step, you will figure out how to find your files that you create in your container on your laptop. The container allows us to have a unified OS environment throughout the class, but you can access the files in the container, just like you would in opening a document or file.
#
# ### Why File Hierarchies Matter
#
# Consistency matters. Like navigating around the house, it’s nice to know where everything is and that items are placed in a logical order (hopefully your kitchenware isn’t found in your bathroom). The same holds true for coding. Knowing where files are, when to use certain code for certain operations, and how to find associated results, data, and figures can not only streamline productivity, but also allow for consistency (even across multiple projects) and shareability.
#
# Where you place your files and how you organize your file structure can be seen as an overall map to your coding projects. As with a map legend, you should establish a set of expectations about where to find parts of the project, and in which order these parts fit (i.e., run) together.
#
# #### Why do it: For Others
#
# Even if you are working on a class assignment, it is best to work under the mindset that your work will be shared and reproduced by others. For that to happen, you need to organize your code such that newcomers can quickly access key parts of your project without looking through documentation or aimlessly clicking through files. In a way, you want others to <i>thank you</i>. They will hopefully thank you for:
#
# <ul>
#     <li>the time saved in learning your project structure</li>
#     <li>being able to collaborate more easily with you</li>
#     <li>quickly learning how your analysis was performed</li>
#     <li>being able to quickly reproduce your code, which adds confidence to both the collaborator and you.</li>
# </ul>
#
# #### Why do it: For you
#
# If you’ve ever organized your desk to clean up both physical and mental space, then your coding projects deserve the same consideration. The time invested in learning how to organize your code now will help you streamline future projects and add consistency between projects. Even if you are working on a quick homework assignment, think about the hundreds of similar homework assignments for which you have to mock up a folder and then finagle some files (we advise against <a href = "http://mitcommlab.mit.edu/meche/wp-content/uploads/sites/8/2019/10/file-structure-messydesktop.jpg">putting everything on your desktop</a>). So whether you’re working on small or big projects, setting a standard structure will add consistency among all of your work and decrease the amount of time it takes to boilerplate your code.
#
#
# > If you want some insight into why it's important for you to gain familiarity with file hierarchies as you will in this course, read the Medium article - "<a href = "https://www.theverge.com/22684730/students-file-folder-directory-structure-education-gen-z">File not found: A generation that grew up with Google is forcing professors to rethink their lesson plans</a>."
#
# ### Step 4.1 - Finding the Container
#
# You can directly access your file by going to the folder location shown when you ran <code>ls</code> in Step 2.4. In my case, it was <code>C:\Users\mmorri22\cse20133\home</code> on my Windows machine.
# <ul>
#     <li>On a Windows machine, you can type or copy/paste into the browswer in File Explorer</li>
#     <li>On an Apple Mac, you can search for the folder through Finder</li>
#     <li>On a Linux machine, you can search for the folder using GNOME Files</li>
# </ul>
#
# In the folder, open the demo.txt file using a simple text editor. For example, on a Windows machine, you can use Notepad. Add in any comment you want and save the file. For example, I entered:
#
#     Welcome back to Notre Dame, and best of luck in all your classes this semester!
#
# Now, go back to the Docker Desktop Container Terminal, and type in <code>ls -l</code>. You will see that the size of demo.txt is greater than 0. When I ran it, this was the output:
#
#     -rwxrwxrwx 1 cse20133-user cse20133-user 79 Aug 11 13:27 demo.txt
#
# This means that the file is <b>79 bytes</b>. In this course, we will learn that each character requires one byte of memory. My message is 79 characters long.
#
# > <b>Visualize It!</b> - I go through Step 4.1 and explain how the container is set up in the Operating System
# [![](http://img.youtube.com/vi/Ytth_bykrEU/mqdefault.jpg)](https://www.youtube.com/watch?v=Ytth_bykrEU)

# %% [markdown]
# ## Step 5 - Installing programs on Linux (in your course container)
#
# Our containers come with a few programs pre-installed, but what if we want more? With a text-based interface like the command line, it’s quite difficult to navigate the web and find a suitable download link. Instead, we use a program called a package manager which can automatically download, install, and update programs. We’ll be using a manager called <code>apt</code>. <code>apt</code> can install many things, including tools to build (or compile), and debug your code. Our containers already come with these tools for your convenience.
#
# > You have already used <code>apt</code> to install <code>vim</code>
#
# To get practice using <code>apt</code>, we’re going to install some fun (and useless) command line programs, but <code>apt</code> is generally the way to go for installing almost anything on your course container.
#
# ### Step 5.1 - Install fortune and cowsay
#
# Using the terminal inside Docker Desktop, use <code>apt</code> to install:
#
# <ul>
#     <li><code>fortune</code> - A program which outputs a random fortune when used.</li>
#     <li><code>cowsay</code> - A program that generates ascii-art of a cow saying text.</li>
#     <li><code>lolcat</code> - A program that generates colors for text.</li>
# </ul>
#
# First, perform these command:
#
#     sudo apt update
#
# This builds an up-to-date index of packages available to download.
#
# Then, for each package, do:
#
#     sudo apt install <package>
#
# So for <code>fortune</code>, <code>cowsay</code>, and <code>lolcat</code> you will do:
#
#     sudo apt install fortune
#     sudo apt install cowsay
#     sudo apt install lolcat
#
# >If you have VS Code open. Close it and re-open it so the programs are refreshed.
#
# You will need to tell the <b>VS Code terminal</b> (not the Docker Terminal) where to find these programs by adding their location to the “PATH”. You can do this by running the following command:
#
#     export PATH=$PATH:/usr/games
#
# Now, try it out! In the VS Code terminal for your container, you can type <code>fortune</code> into your terminal to see a prediction for your semester, and can use cowsay by typing <code>cowsay</code> "<some string>". And you can combine them using <code>fortune | cowsay</code>
#
# Here is an example from my run:
#
#     $ fortune
#     You are confused; but this is your normal state.
#     $ cowsay "The CSE 20133 students will do great this semester!"
#      ______________________________________
#     / The CSE 20133 students will do great \
#     \ this semester!                       /
#      --------------------------------------
#             \   ^__^
#              \  (oo)\_______
#                 (__)\       )\/\
#                     ||----w |
#                     ||     ||
#
# <img src = "https://cloud.githubusercontent.com/assets/1307927/11684261/b6ca25f4-9e70-11e5-8018-fb6c033cbede.png" width=300px height=300px>
#
# Finally, you can use <code>>></code> to append text to an existing file.
#
#     $ fortune | cowsay | lolcat >> demo.txt
#
# Go to the VSCode, and you will that your <code>demo.txt</code> file has already been updated with a <code>cowsay</code> output.

# %% [markdown]
# ## Step 7 - Git
#
# <b>Git</b> is an awesome version control tool for your code. In essence, it allows you to continuously save your project as a sequence of small changes instead of one final thing. Some of the cool things this grants you are:
# <ul>
#     <li><b>Reverting changes</b> in case your code breaks.</li>
#     <li><b>Merging changes with partners</b>, even if you’re working on the same file.</li>
#     <li><b>Having multiple branches</b>, to test out implementations without ruining your code.</li>
#     <li><b>Retrieving stencil code and handing in solutions</b>, like you’ll be doing throughout the semester!</li>
# </ul>
#
# You will use Git to post your code to be accessed for grading. For these directions, as well as for any Git-related issues, I <i>strongly</i> recommend using the Slack, asking a TA, or reaching out to Dr. Morrison to ask questions or get 'Git' help because <b>Git documentation is notoriously riddled with errors</b>. I have designed the assignments so that you will not be performing advanced Git commands in your first course. I recommend finding a TA or myself before going to the online documentation, as we have likely seen the issue you've encountered. Nothing takes more time in Office Hours than right after a student says "well, I found a website on Git that suggested I..."
#
# ><b>Note</b>: Follow along with these directions, even if you have created a GitHub account. GitHub recently ( 8/13/2021 ) changed how accounts are authenticated. If you used a GitHub account before, but have not used it since last August, your password likely will not work. Review Step 8 below to perform Two-Factor Authentication.
#
# > <b>Video</b>: To get a high-level understanding of what GitHub does, check out this video. Click on the image below to watch the video.

# %% [markdown]
# ### Step 7.1 - Git Setup
#
# There are a ton of resources out there to learn about Git, so we won’t try to recreate them. We will provide you enough information to perform basic Git commands, and occasionally link to tutorials if you wish to expan your skills.
#
# Before you start running Git commands, you’ll need to configure your name and email in Git. In the VS Code terminal, use your name and email:
#
#     git config --global user.name "Matthew Morrison"
#     git config --global user.email "mmorri22@nd.edu"
#
# Next, you will cache your GitHub credentials to avoid needing to entering them in each time.
#
#     git config --global credential.helper store
#
# If you are not already signed up to GitHub with your nd.edu email address, add it to your profile so that GitHub knows to correctly attribute commits to your username.
#
# ### Step 7.2 - GitHub Account Setup
#
# <b>1.</b> Go to <a href = "https://github.com">github.com</a>. On the right hand side, you will see a prompt for "Sign Up". On the next page, you will be prompted for your a box that requests a Email, a Password, and a User Name.
# <ul><li>I strongly recommend you use your Notre Dame email and NetID. Most students will also use their Notre Dame NetID as their username if it is available. You do not need to receive product updates and announcements via email.</li></ul>
#
# <b>2.</b> Press Continue. You will be asked to solve a small puzzle to <a href = "https://www.youtube.com/watch?v=s6VtOMjlSbA">prove you are not a robot</a>. Once you have done that, select "Join a free plan". GitHub will send you a confirmation via email.
# <ul><li>Go to your email, and verify your account by entering the 6-digit code sent to you.</li></ul>
#
# <b>3.</b> On the next page, where you are prompted, "How many team members will be working with you?", select 1. Then, indicate you are a Student, and select Continue.
#
# <b>4.</b> On the next page, there is no need to select anything. Click Continue at the bottom of the page.
#
# <b>5.</b> On the next page, select Continue for Free. After a Star Wars-esque graphic is displayed , you will be in your repository.
#
#
# ### Step 7.3 - SSH Key Generation
#
# You are going to generate an <b>SSH key</b> and and then add the key to your GitHub account. The <a href = "ssh.com/academy/ssh-keys">SSH Key</a> is part of an encryption protocol to keep your transferred files secure.
#
# <b>1.</b> Go to your VS Code Terminal.
#
# <b>2.</b> In the command line, type the following command (modifying for your email):
#
#     ssh-keygen -t rsa -b 4096 -C "NDNetID@nd.edu"
#
# Be sure to replace NDNetID with your Notre Dame NetID that you used to create your GitHub account. Leave the quotation marks. For example, my command was <code>ssh-keygen -t rsa -b 4096 -C "mmorri22@nd.edu"</code>
#
# <b>3.</b> Press Enter three times. You do not need to enter a passphrase for your SSH key.
#
# <b>4.</b> Now go to VSCode. Assuming your container is activated,you will be able to see a new folder on the left hand side, <code>.ssh</code>. Open that folder, and then open the file <code>id_rsa.pub</code>
#
# <b>5.</b> Go to your GitHub page (assuming you are logged into your account)
# <ul>
#     <li>On the top right, select the icon for your account.</li>
#     <li>From the drop-down menu, select "Settings".</li>
#     <li>On the next page, select "SSH and GPG Keys" on the left panel sidebar.</li>
#     <li>Click on the button "New SSH Key"</li>
#     <li>Add a Title of your choosing. (For example ND-GitHub)</li>
#     <li>Paste the contents of your <code>id_rsa.pub</code> file into the Key field, and then click "Add SSH Key." If prompted, confirm your GitHub password.</li>
# </ul>
#
# ### Step 7.4 - Two-Factor Authentication (2FA)
#
# Starting 8/13/2021, all GitHub users are required to use Two-Factor Authentication (2FA) for their accounts.
#
# <b>1.</b> From your Github account, go to Settings
#
# <b>2.</b> On the left, go to <b>Developer Settings</b>. Then, on the left, go to <b>Personal Access Token</b>. On the pull down menu, select <b>Tokens (classic)</b>.
#
# <b>3.</b> On the top left, select <b>Generate New Token</b>, and then on the pull-down menu, select <b>Generate New Token (classic)</b> (If prompted, give your password).
# <ul>
#     <li>Fill in the form</li>
#     <li>In the "Note" form, type "CSE 20133 GitHub Repo"</li>
#     <li>Under Expiration, select No Expiration.</li>
#     <li>Under "Select Scopes", select "repo", which will also select all the items underneath.</li>
#     <li>This is the only choice you will need to make to perform all the necessary tasks for this course.</li>
# </ul>
# <b>4.</b>At the bottom, select "Generate Token"
#
# <b>5.</b>Copy the generated Token, it will be something like <code>ghp_sFhFsSHhTzMDreGRLjmks4Tzuzgthdvfsrta</code>. I recommend you keep a secure copy of this token somewhere on your laptop.
#
# > Follow the advice of the Git page: "Make sure to copy your personal access token now. You won’t be able to see it again!"
#
# Whenever you push to Git, you will need to use this Personal Access Token, not your GitHub password.
#
#
# ### Step 7.5 - GitHub Course Folder Creation and Cloning
#
# In this section, you will create your GitHub repository for the course, and learn how to checkout a branch and push to GitHub. To do this, be sure to be logged into your GitHub account, as well as have your Docker and VSCode open.
#
# > <b>Cloning from GitHub</b>: There is a video after these next 6 steps which shows the whole process. If you are confused or get lost, please refer to the video, and then to the Slack.
#
# <b>1.</b> Go to the following link for the Fall 2024 semester:
# https://classroom.github.com/a/u_pKAOXt. At that link, you will see a welcome that says "Join the classroom: Notre Dame - Fall 2024 - CSE 20133".
#
# <b>2.</b> To join the GitHub Classroom for this course, please select yourself from the list below to associate your GitHub account with your Notre Dame netID.
#
# <b>3.</b> You will be asked to confirm that you accept the assignment. Please do so.
#
# <b>4.</b> This will create a private cse20133-@USERNAME repository under your own account and linked to the cse20133-f24 organization.
#
#     For example, my username is mmorri22, so my repository would be cse20133-mmorri22
#
# For the rest of the steps, replace <code>@USERNAME</code> with your GitHub user name, as <code>@USERNAME</code> is a generic variable.
#
# <b>5.</b> You will now clone the repository. Select the link highlighted in blue on the GitHub Classroom page under "Your assignment repository has been created:"
#
# <b>6.</b> On that page, there will be a blue box that says "Quick setup — if you’ve done this kind of thing before". In that box, there will be a link of the format <code>https://github.com/cse20133-f24/cse20133-@USERNAME.git</code>.
#
# Using that command, go to the <b>Terminal in VS Code</b> and perform a <code>git clone</code> as shown below. Be sure you are in the <code>/home/cse20133-user</code> folder. This setup will ensure your code is properly run in the Container.
#
#     git clone https://github.com/cse20133-f24/cse20133-@USERNAME.git
#
# >For my example, it would be <code>git clone https://github.com/cse20133-f24/cse20133-mmorri22.git</code>
#
# In my example, I just opened VS Code, and I am in the <code>home</code> directory. I <b>change directories</b> into <code>cse20133-user</code> and then ran my specific <code>git clone</code> command.
#
# ><code>cse20133-user@da240cb02f7e:/home> <font color = "red">pwd</font></code><br>
# ><code>/home</code><br>
# ><code>cse20133-user@da240cb02f7e:/home> <font color = "red">cd cse20133-user</font></code><br>
# ><code>cse20133-user@da240cb02f7e:~ > <font color = "red">pwd</font></code><br>
# ><code>/home/cse20133-user</code><br>
# ><code>cse20133-user@da240cb02f7e:~ > <font color = "red">git clone https://github.com/cse20133-f24/cse20133-mmorri22.git</font></code><br>
# ><code>Cloning into 'cse20133-mmorri22'...</code><br>
# ><code>remote: Enumerating objects: 20, done.</code><br>
# ><code>remote: Counting objects: 100% (20/20), done.</code><br>
# ><code>remote: Compressing objects: 100% (17/17), done.</code><br>
# ><code>remote: Total 20 (delta 3), reused 18 (delta 1), pack-reused 0</code><br>
# ><code>Unpacking objects: 100% (20/20), 7.39 KiB | 10.00 KiB/s, done.</code><br>
#
# <b>7.</b> The command created a new folder <code>cse20133-@USERNAME</code>. You will see the new folder in the hierarchy on the left hand side on VSCode. Additionally, you will see it if perform <code>ls</code>. Descend into the folder.
#
#     ls
#     cd cse20133-@USERNAME
#
# <b>8.</b> Create a folder called hw1, and descend into that folder.
#
#     mkdir hw1
#     cd hw1
#
# <b>9.</b> You will move the demo.txt file into the Git folder. Run the following command (including the space and period at the end):
#
#     mv ../../demo.txt .
#
# This command has three parts:
#
#     mv - Move
#     ../../demo.txt - The origin file. Go up two levels (../..), and select demo.txt
#     . - Move it to the current folder
#
# Use the <code>pwd</code> and <code>ls</code> commands to see the new location. Go into VSCode and see how this has been moved in the hierarchy. The old demo.txt will have a strike through. Close that file. Open the demo.txt in its new location.
#
# <b>10.</b> Next, you will learn how to obtain a file from online.
#
# <code>wget</code> is a command that will make a copy of a public file in your local directory. In this case, you are obtaining a <code>hello.c</code> file.
#
#     wget https://raw.githubusercontent.com/mmorri22/cse20133/main/homeworks/homework01/hello.c
#
# >Note: You need to use <code>raw.githubusercontent.com</code> version of the file when running <code>wget</code> from GitHub, or else you will download the HTML that used to render hello.c at the GitHub page
#
# You will now compile and run the program with these two commands:
#
#     gcc hello.c -o hello
#     ./hello
#
# Done successfully, the terminal will print <code>"Hello, World"</code>
#
# <b>11.</b> Next, open hello.c in VSCode. Change the name and email from Professor Morrison's information to your information.
#
# Additionally, change the message from "Hello, World!" to a message of your choosing. Be sure not to use any double quotes <code>"</code> in your message.
#
# Go back and compile and run the program with these two commands:
#
#     gcc hello.c -o hello
#     ./hello
#
# A successful run will now print your message.
#
# Run the command <code>ls -l</code>. You will see that the <code>hello</code> is much larger than the code file. We will now delete the <b>executable</b> to preserve space on your machine.
#
#     rm hello
#
# ### Step 7.6 - GitHub Push
#
# <b>1.</b> In this final step, you will push your repository to the GitHub. These steps assume you are still in the <code>hw1</code> folder. You will always upload your code (which we will not call <b>push</b>) from the cse20133-$USERNAME folder. First, move up one level, and then check that you are in the correct folder
#
#     cd ..
#     pwd
#
# <b>2.</b> We will initialize the folder as a Git folder.
#
#     git init
#
# <b>3.</b> To add <b>all</b> the files and file updates (including deletions), run the following command:
#
#     git add --all
#
# <b>4.</b> Then, we will <b>commit</b> changes, you will run the following command (with a unqiue message indicating the purpose of the code update.)
#
#     git commit -m "First CSE 20133 GitHub Push!"
#
# <b>5.</b> Next, we will set the origin using the link from your created in Step 7.5.6.
#
#     git remote add origin https://github.com/cse20133-f24/cse20133-@USERNAME.git
#
#     git branch -M main
#
# <b>5.</b> Now, we will <b>push</b> the code to GitHub
#
#     git push -u origin main
#
# Put in your GitHub username. When your GitHub password is requested, <i>enter your GitHub SSH Token that you created and saved</i>, not your GitHub password.
#
# Now, go back to your GitHub repository. You should now see a <code>hw1</code> folder. When you go into it, you will be able to see your <code>demo.txt</code> and <code>hello.c</code> files.

# %% [markdown]
# ## Congratulations, you have successfully completed Homework 1, and you will now be able to participate in in-class coding opportunities and Homework assignments.
