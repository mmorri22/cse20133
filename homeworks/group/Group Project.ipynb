# %% [markdown]
# # Group Project - Develop Your Own Data Visualization Problem

# %% [markdown]
# <b>Due Date</b>: 12/7/2023 at 11:59pm<br>
# <b>Optional Extension</b>: 12/12/2023 at 11:59pm<br>
# <b>Points</b> - 2000 points<br>
#
# <b>You will work in groups of 3 or 4 students</b>.
#
# <b>Your group will submit</b>:
# <ol>
#     <li>An Explanatory Article detailing Your Project and design process</li>
#     <li>An “Interesting” Component where you use Matplot++ and C++ to perform the visualization</li>
# </ol>
#
# > <b>What does "Optional Extension" mean?</b> - As a Notre Dame professor, I am not permitted to make any assignment due during your Reading Days, so I am setting a <b>formal Due Date</b> of 12/7/2023. However, if you choose on your own to work on the project past the due date, you have an <b>Optional Extension</b> 12/12/2023 at 11:59pm.
#
# > This optional extension is also designed to account for different group members having different values of extension tokens (meaning <b>no assignments will be accepted past the optional extension, so no extension tokens may be used</b>.)

# %% [markdown]
# In this <b>group project</b>, you will combine concepts from the second half of the semester to build a program that creates a unique data visualization of a concept that can be challenging to visualize. You will use the following skills:
# <ul>
#     <li>Perform independent look up information online</li>
#     <li>Reading in from a file from the command line</li>
#     <li>Building a C++ Class (or multiple classes!) to store data visualization</li>
#     <li>Use Matplot++ to perform the Data Visualization</li>
# </ul>

# %% [markdown]
# # Data Visualization
#
# In Lecture 36-38, you observed how to <b>process</b>, <b>store</b>, and present information usinf the <a href = "https://alandefreitas.github.io/matplotplusplus/">Matplot++</a> C++ extension tool. You saw a few visualizations of data:
# <ul>
#     <li>In <a href = "https://github.com/mmorri22/cse20133/tree/main/inclass-sols/lec37">Lecture 37 In-Class</a>, you observed how to plot an Electric Field in 3-dimensions</li>.
#     <li>In <a href = "https://github.com/mmorri22/cse20133/tree/main/inclass-sols/lec38">Lecture 38 In-Class</a>, you observed how to visualize different types of Iris plants</li>.
# </ul>
#
# Now you will research and implement your <i>own idea</i> to visualize with data! To do that, you’ll probably a few several papers, blog posts, book chapters, etc. to see what you find.
#
# > One of the purposes of this assignment is to provide you with experience you can <b>quantify on a resume</b> to position you for better internships and jobs. <b>Projects count as experience!</b> I strongly recommend you work on a project in an area you want to work in when you graduate, or that you find quite interesting, as that will motivate you in this assignment.
#
# > <b>Crucial Academic Integrity Note</b>: your write-up should be your own words and your own presentation. Your write-up should not be a paraphrase of your sources. That is, if I were to line up the sources you’ve cited and the paper you wrote, I shouldn’t feel as though I’m reading the same thing twice. You should be aiming for synthesis rather than recall.<p>
# > Regardless of what you do, you must cite your sources in your write-up, and not just if you’re taking a passage from somewhere else. Remember, it’s plagiarism to take another person’s work and present it as your own! As you move on in your career, this is something professors and employers will take much more seriously than you may be accustomed to. That’s why plagiarism rules apply even if you aren’t literally copying text or figures.<p>
# > You're welcome to share drafts of your writeup with other CSE 20312 students to get feedback, and in fact you're encouraged to do so. Just make a note of it somewhere in your write up.

# %% [markdown]
# ### Submission Part 1 - The Explanatory Article
#
# Your first major deliverable is an explanatory article on your topic. The goal of this article is to guide a reader on a journey from ignorance to understanding. This means that you’ll want to explain your concepts using a mix of high-level intuitions, drawings, animations, and interactive demonstrations.
#
# Think of this as more of an exercise in good storytelling rather than an exercise in writing a journal article. Journal articles are designed to be compact. There’s an expectation that someone reading a paper will sit down with scratch paper and take notes, following along with the reasoning and pausing to verify intermediate results if necessary. In that sense, a journal article can be thought of as “knowledge concentrate” – you need to add some water and stir quite a bit to get something edible out of it.
#
# On the other hand, what I’m asking you to do is to write something that is lucid, clear, well-motivated, and easy to follow. Be conversational. Draw lots of pictures. Provide motivation for the topic and each piece. Give intuitive explanations before going into more difficult math. Create some animations showing how things work, or give the user interactive controls they can use to step through things.
#
#
# #### Required Elements
#
# You may come up with creative ways to perform this Explanatory Article, but it must include the following:
#
# 1) <b>Group Members</b> - 25 points will be for every group member to include their name and netIDs for ease of entering grades.
#
# 2) <b>Location of Code</b> - Another 25 points will include an indication of which group member pushed the code to GitHub. Only one group member is required to push as long as it is properly documented.
#
# 3) <b>The Topic Being Visualized</b> - In your own words will describe the concept you are going to visualize. Your description must inlude a high-level technical description of the topic, and the challenges with conventional approachs to visualizing the data.
#
# 4) <b>Your Approach</b> - You must describe in detail the approach to reading in and storing data (the C++ class itself), how you are processing the data, and your approach to producing the visualization
#
# 5) <b>Description of the output</b> - You should desribe how to run your code (how someone who has your code will replicate your results), as well a description of the what the visual is telling us.
#
#
# #### Evaluation of the Explanatory Article
#
# Your explanatory article will be evaluated on the following metrics:
#
# <b>Clarity</b>: How clear is your exposition on the topic? Does it flow naturally in a way that guides the reader through a difficult idea, or does it force the reader to keep pausing to refer back to concepts that are described earlier? Does it contain speling, grammatically, or fᵒʳ mₐTt iⁿg errors, or is it well-proofread? Remember that your goal isn’t to just brain-dump everything you’ve learned; it’s to explain how something works and why it’s worth learning about in the first place.
#
# <b>Intuition</b>: How well does your write-up communicate the intuition behind your topic? For example, if there’s some key technical lemma necessary for things to work properly, did you just present the concept “as-is,” or did you help the reader contextualize what it says and understand why it’s true? If there’s some unusual choice of a constant, can you account for why that constant is chosen that way? And if there’s something that’s surprising, can you provide an explanation as to why, in retrospect, it might not be as surprising as initially perceived?
#
# <b>Rigor</b>: This is an engineering class, after all, and so we will be looking at how rigorous you are in your write up. You don’t need to prove everything, but you shouldn’t hand-wave away every result. Pick a few interesting bits here and there and really dive deep into them! This is something that, hopefully, you’ll already have done when reading up on the topic in the first place.
#
# ### Some Good Examples of Explanation
#
# <ul>
#     <li><a href = "https://www.redblobgames.com/maps/terrain-from-noise/">Making Maps with Noise Functions</a> by Amit Patel. This article explores noise functions and how to use them to generate realistic terrains. The interactive slides make this a joy to explore and provide a powerful intuition for how everything fits together.</li>
#     <li><a href = "https://cgi.di.uoa.gr/~ewcg06/invited/Seidel.pdf">Understanding the Inverse Ackermann Function</a> by Raimund Seidel. This talk, which was given by a computer scientist who published a new analysis of the union-find data structure, does a great job motivating both the result that he proved and explaining what on earth the Ackermann inverse function actually is. It blends technical rigor with a conversational tone and good use of diagrams.</li>
#     <li><a href = "https://ncase.me/trust/">The Evolution of Trust</a> by Nicky Case. This interactive exploration of the iterated prisoner’s dilemma gives an intuitive feel for the game and the different strategies involved, and in doing so surveys the literature in a deep but approachable way. Is this an “article” in the conventional sense? Nope! But would I be okay with you submitting something like this? Oh yes, definitely!</li>
#     <li><a href = "https://www.youtube.com/watch?v=WUvTyaaNkzM">The Essence of Calculus - Chapter 1</a> by Grant Sanderson. This video on integrals masterfully uses visualizations to motivate basic concepts of calculus in a way that both foreshadows how more advanced topics work and makes the whole idea of an integral intuitive and worthwhile. (And yes, if you’d like to submit a video explanation, go right ahead! But I'm still going to expect it to be rigorous. )</li>
#     <li><a href = "https://www.youtube.com/watch?v=RdYHljZi7ys">How the first transistor worked</a> by Bill Hammack - A clever description of the invention of the very first transistor. This is a great example of conversation tone that is rigorous, and uses an example of visualization to make a challening topic easier to understand.</li>
# </ul>

# %% [markdown]
# ### Submission Part 2 - The “Interesting” Component - The Code Assignment
#
# You must have a C++ program to perform the visualization. You must have:
#
# <ul>
#     <li>A class that stores your data (like the Iris.cpp / Iris.h class in Lecture 38 In Class)</li>
#     <li>A separate library that performs these tasks (like the preprocessor.cpp and preprocess.h files in Lecture 38 In-Class</li>
#     <li>You must read in the data from a file, just like the iris.data in Lecture 38 In-Class</li>
#     <li>That dataset must be open source, and sufficiently large to justify the need for data visualization in your Explanatory article (my data set for iris.data in Lecture 38 had 50 points, which may be more than you need. The crucial aspect is to <i>justify</i> it.)
#     <li>You must use <b>Matplot++</b> to perform the visualization</li>.
#     <li>Your visualation using Matplot++ must include some added visualization techniques compared to a basic graph with the objective of making </li>
# </ul>
#
# #### Visualization with Matplot++
#
# You are not limited to the visualizations we have implemented in class. There is an entire website full of coding examples using Matplot++:
# <ul><li><a href = "https://alandefreitas.github.io/matplotplusplus/">https://alandefreitas.github.io/matplotplusplus/</a></li></ul>
#
#
#
# #### Required Files
#
# Your submission must be split into (at least) seven files:
# <ul>
#     <li>The .h and .cpp files for storing the Class to save the data</li>
#     <li>The .h and .cpp files for processing the data</li>
#     <li>The main driver function</li>
#     <li>Makefile</li>
#     <li>An input with the data file</li>
# </ul>
#
# > <b>Why might I need more files?</b> - You may need more files if you want to add another library or another class, or you have several data input files you want to use.
#
# The code must compile using the command <code>make project</code>. If your class for storing information is in <code>project_class.cpp</code>/<code>project_class.h</code>, the library is in <code>project_lib.cpp</code>/<code>project_class.h</code>, the main driver is in <code>project.cpp</code>, and the data is <code>data.txt</code> the compilation should appear as follows
#
#     > make project
#     g++ -std=c++2a -O2 -g -Wall -Wextra -Wconversion -Werror -c project_class.cpp -I/usr/include/python3.8 -lpython3.8
#     g++ -std=c++2a -O2 -g -Wall -Wextra -Wconversion -Werror -c project_lib.cpp -I/usr/include/python3.8 -lpython3.8
#     g++ -std=c++2a -O2 -g -Wall -Wextra -Wconversion -Werror -c iris_visual.cpp -I/usr/include/python3.8 -lpython3.8
#     g++ -std=c++2a -O2 -g -Wall -Wextra -Wconversion -Werror -o project project_class.o project_lib.o project.o -I/usr/include/python3.8 -lpython3.8 -lm
#     > valgrind --leak-check=full --track-origins=yes ./project data.txt project
#
# > <b>Note:</b> Your <code>project_lib.cpp</code>/<code>project_class.h</code> and <code>project_class.cpp</code>/<code>project_class.h</code> files may have unique names. But keep <code>project.cpp</code> for the main driver program.

# %% [markdown]
# ## PDF Report - Submission Steps
#
# <b>Only one group member needs to submit the PDF</b>. You can follow these directions to ensure your group members are linked to the submission:
#
# [![IMAGE ALT TEXT HERE](https://img.youtube.com/vi/rue7p_kATLA/0.jpg)](https://www.youtube.com/watch?v=rue7p_kATLA)
#
# <ol>
#     <li>Go to the following link: <a href = "https://canvas.nd.edu/courses/74671/assignments/201987">Group Project Gradescope Submission</a></li>
#     <li>Step 2: Upload the PDF you have created for your group submission through the applet.</li>
#     <li>Step 3: Hit Submit in the bottom right</li>
#     <li>Step 4: At the top right, the submitter must select the other group members. Select "View or edit groups" under the submitter's name (which is there by default)</li>
#     <li>Step 5: Select your group members from the class roster. Then select Add when done.</li>
#     <li>Step 6: Double check that the groups are done correctly. The video above shows steps on how to fix a mistake (starting at 1:27)</li>
# </ol>

# %% [markdown]
# ## For this programming assignment, you will submit the problems via GitHub.
#
# As we progress through the semester, we will add more programming standards. For now, here are a few you can reasonable be expected to follow on this assignment at this point of the semester:
#
# 1 - Your code must be easy to read. Bunched together, difficult to read code will receive point deductions.
# <ul><li>If you are unsure, ask a TA. The TAs will be the ones reading your code, so if they are able to easily read your code, then you are in good shape.</li></ul>
#
# 2 - Your code must contain variables that indicate what you are performing in your code. Imagine if Lord of the Rings had four Hobbits, a, b, c, and d instead of Frodo, Samwise, Merry, and Pippin. That would be a tough read!
# <ul>
#     <li>Good example: <code>double radius_solution_1;</code></li>
#     <li>Bad example: <code>double x;</code></li>
# </ul>
#
# 3 - Your code must have proper tabbing to show levels (i.e., if statements, for loops, ect.)
#
# 4 - Your code must promote modularity (i.e. function calls, division of tasks, code reuse, ect.), as well as separation into libraries and "separate compilation" using Makefiles.
#
# 5 - The use of <code>using namespace std;</code> in C++ submissions in this course is <i>forbidden</i>. It's inclusion and use will result in an automation 250 point deduction.
#
# 6 - You must use the <code>-std=c++2a</code> in C++ submissions in this course.
#
# 7 - For function calls and class methods, you must promote the use of const (i.e. if the STL values do not change, you must use const.

# %% [markdown]
# ## Submitting Your Assignment: Committing and Pushing Through VS Code
#
# By the due date, you must <code>commit</code> and <code>push</code> directly from the VS Code.
#
# <b>Only one group member needs to push to GitHub</b>. Just be sure your Explanatory Articles says <i>whose</i> account it is under.
#
# First, you <i>must</i> run <code>make clean</code> to ensure you do not push any executable or object files. You will receive a deduction of 100 points if you include executables or object files in your GitHub.
#
#     make clean
#
# From the VS Code Terminal:
#
#     cd ..
#
# At this point, you should be in the <code>cse20133-@USERNAME</code> folder
#
#     git add --all
#     git commit -m "Group Submission: [Group NetIDs Here]""
#     git push -u origin main
