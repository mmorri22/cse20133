# %% [markdown]
# # Midterm Exam Review

# %% [markdown]
# > <font color="red"><b>Note: You are expected to build up your own solutions to these problems, and answers will not be posted beyond what is covered in the In-Class Exam Review</b></font>.
#
# ## How the Exam will be Given
#
# Unless you have an accommodation from the Sara Bee Center or under quarantine you must take this Exam in the lecture room at the designated class time.
#
# Me and the Teaching Assistants will hand out exams 5 minutes prior to the beginning of class. Students may begin them at 9:25am and when they have put their non-permitted items away. You must hand in your Exam when I indicate time is up. Continuing to work on the exam after time is called will result in disqualification of your Exam.
#
# ## Exam Format
#
# The problems on the Exam will be similar in format to the Homework problems. You will not be asked to write and compile code. (You can be asked what an issue is with a code segment based on an error message)
#
# This exam is closed book: You may not use any website, books, HW solutions, Hogwarts Owls, voodoo magic, other kinds of magic, smoke signals, or your class notes.
#
# If you are caught using any unauthorized resource, you will receive an automatic 0 on the Exam and a referral to the Notre Dame Academic Honor council.
#
# The Exam will have one "Evaluation" question where the answer will not be readily obvious that is not quite like the Homework questions.
#
# > You know everything you need to know to solve the problem, and the objective is for you to show that you can combine your memorization, understanding, and application skills in an evaluative manner befitting an engineer.

# %% [markdown]
# ## Building your Exam Study Guide
#
# The objective of these problems is for you to practice the problems to set you up for success.
#
# These set of problems are longer than the actual exam. But if you can solve these problems independent of the keys or your notes, you will have set yourself up well for success on the Exam.
#
# The general outline for the Exam will be covered in class on the Monday prior to the Exam.

# %% [markdown]
# ## Example Questions
#
# Work to develop an example study guide for these problems. You are welcome to develop a guide with your classmates. We will also work on several problems during the class before the Exam.
#
# > <b>Pro tip:</b> Develop variants of problems to build your own guide!
#
# > <b>Note:</b> The number of problems in this guide are designed to help you gain practice and mastery of the topics. This does not reflect the length of the actual exam (there are many more problems here)
#
# <b>1.</b> Binary Conversion
#
# 1-a) Convert the following decimal to binary. Represent as a seven-bit signed integer
#
#     57
#
# 1-b) Convert the following decimal to binary. Represent as a seven-bit signed integer
#
#     -42
#
# 1-c) Convert the following six-bit signed integer in binary to decimal.
#
#     110110
#
# 1-d) Conver the following six-bit unsigned integer in binary to decimal.
#
#     110110
#
# <b>2.</b> Hexadecimal
#
# Convert the following from hexadecimal to a signed integer.
#
#     0x9c4b
#
# Convert the same value from hexadecimal to an unsigned integer.
#
# Convert the following from decimal to hexadecimal. Use four hexadecimal characters in your solution.
#
#     -3482
#
# <b>3.</b> Convert the following IEEE 754 Single Precision Formats to decimal
#
#     0 10001100 11010000000000000000000
#
#     1 01111101 10100000000000000000000
#
# <b>4.</b> Given a set of output specifiers, identify their type:
# <ul>
#     <li>%d</li>
#     <li>%u</li>
#     <li>%f</li>
#     <li>%lf</li>
#     <li>%c</li>
#     <li>%p</li>
#     <li>%s</li>
# </ul>
#
# <b>5. Given the following C code segment, state the expected output:</b>
#
#     #include <stdio.h>
#
#     int main(void){
#
#          int i = 5, j = -10, k = -15;
#
#          int sum = i + j + k;
#
#          fprintf(stdout, "%x\n", sum);
#
#          return 0;
#     }
#
# <b>6.</b> Write a while loop in C that adds every number from 1 to 100
#
# <b>7.</b> Write a for loop in C that calculates the factorial value 25!
#
# <b>8.</b> Write a do-while loop in C that takes a signed integer and subtracts 2 on every loop until the value is less than 0.
#
# <b>9.</b>The following code segment does not pass our code Production Quality Compilation rules. Briefly state the error and describe why our flags cite this error.
#
#     #include <stdio.h>
#
#     int main(){
#
#         float the_float = 3.1;
#
#         fprintf(stdout, "%f\n", the_float );
#
#         return 0;
#     }
#
# <b>10.</b>The following code segment does not pass our code Production Quality Compilation rules. Briefly state the error and describe why our flags cite this error.
#
#     #include <stdio.h>
#
#     int main(){
#
#         double d_1 = 0.1;
#         double d_2 = 0.2;
#
#         if( d_1 < d_2 ){
#             fprintf( stdout, "%lf %lf\n", d_1, d_2 );
#         }
#     }
#
# <b>11.</b>The following code segment does not pass our code Production Quality Compilation rules. Briefly state the error and describe why our flags cite this error.
#
#     #include <stdio.h>
#
#     int main(){
#
#         float the_float = (float)3;
#
#         switch( the_float ){
#             case 2:
#                 fprintf(stdout, "False\n" );
#                 break;
#             case 3:
#                 fprintf(stdout, "True\n" );
#                 break;
#             default:
#                 fprintf(stdout, "Default Case\n");
#         }
#
#         return 0;
#     }
#
# <b>12.</b> Match the following terms with the corresponding definitions
#
# Terms:
# <ol>
#     <li>Header File</li>
#     <li>Makefile</li>
#     <li>Source Files</li>
#     <li>Object Files</li>
#     <li>Linking</li>
#     <li>Executable</li>
# </ol>
#
# Definitions:
#     A. File used to run the program on the machine
#     B. Contains C function declarations for function reuse
#     C. Contains formatted machine code
#     D. The C files written by the programmer
#     E. Combining the objects into an executable file
#     F. Contains commands for compiling C programs
#
# <b>13.</b> Match the following terms with the corresponding definitions for Makefiles
#
# Terms:
# <ol>
#     <li>Explicit Rule</li>
#     <li>Implicit Rule</li>
#     <li>Variable Definition</li>
#     <li>Directive</li>
#     <li>Comment</li>
# </ol>
#
# Definitions:
#     A. Use a # to inform the reader about the meaning
#     B. A line that specifies a text string value that can be substituted into the code later
#     C. When and how to remake one or more files based on inferred instructions
#     D. When and how to remake one or more files based on direct instructions
#     E. an instruction for make to do something special while reading the Makefile
#
# <b>14.</b> Match the following compiler flags with the corresponding meaning
#
# Flags:
# <ol>
#     <li>gcc</li>
#     <li>-O2</li>
#     <li>-g</li>
#     <li>-std=c2x</li>
#     <li>-Wall</li>
#     <li>-Wextra</li>
#     <li>-Wconversion</li>
#     <li>-Werror</li>
# </ol>
#
# Meanings:
#
#     A. Make all warnings into errors.
#     B. Includes the ANSI C2020 and beyond standards
#     C. Enables warnings when implicit type casting occurs
#     D. Reduce compilation time
#     E. Enables some extra warning flags that are not enabled by –Wall
#     F. Tells the compiler to produce debugging information
#     G. Enables warnings based on the ANSI C99 standard
#     H. GNU Compiler Collection
#
# <b>15.</b> Given the following code segment, write two lines of code that will read in the input variables using fscanf, and then print them using fprintf. For simplicity, read them and print them in the exact order as shown in main below. Be sure to meet the <code>std=c2x</code> PQC flag.
#
#     #include <stdio.h>
#     #include <stdlib.h>
#
#     int main()
#     {
#
#         int int_input;
#         char char_input[50];
#         float float_input;
#         double double_input;
#
#         // fscanf and fprintf statements would go here
#
#         return 0;
#     }
#
# <b>16.</b> State the values that the 6 fprintf statements will print. Assume the following addresses: (Writing the last three hex digits is sufficient for full credit)
#
# Address of register x  is: <code>0x7ffcdedadb10</code>
#
# Address of register y  is: <code>0x7ffcdedadb14</code>
#
# Address of register p1 is: <code>0x7ffcdedadb18</code>
#
# Address of register p2 is: <code>0x7ffcdedadb20</code>
#
# </b>
#
#
#     #include <stdio.h>
#
#     int main()
#     {
#
#         int x = 14;
#         int y = 22;
#
#         int *p1 = &x;
#         int *p2 = &y;
#
#         fprintf( stdout, "%x\n", *p1 );
#
#         fprintf( stdout, "%d\n", *p2 );
#
#         fprintf( stdout, "%p\n", p1 );
#
#         fprintf( stdout, "%p\n", &p1 );
#
#         fprintf( stdout, "%p\n", &y );
#
#         fprintf( stdout, "%p\n", &p2 );
#
#         return 0;
#     }
#
# <b>17.</b> Given the following code and output, match the results to the data/memory value.  (Hint, focus on the last three hexadecimal values for addresses)
#
# Address of a in main = <code>0x7ffd47ac75a0</code>
# Address of b in main = <code>0x7ffd47ac75a4</code>
# Address of val_a in func = <code>0x7ffd47ac7578</code>
# Address of val_b in func = <code>0x7ffd47ac7570</code>
#
#
#     #include <stdio.h>
#
#     void func( int* val_a, int* val_b){
#
#         fprintf( stdout, "%p %p\n", val_a, val_b );
#
#         fprintf( stdout, "%p %p\n", &val_a, &val_b );
#
#         int temp_1, temp_2;
#
#         if( *val_a <= * val_b ){
#             temp_1 = *val_a;
#             temp_2 = *val_b;
#         }
#         else{
#             temp_1 = *val_b;
#             temp_2 = *val_a;
#         }
#
#         *val_a = temp_1;
#         *val_b = temp_2;
#
#     }
#
#     int main(){
#
#         int a = 25;
#         int b = 10;
#
#         func( &a, &b );
#
#         fprintf( stdout, "%d %p %d %p\n", a, &a, b, &b);
#
#         return 0;
#
#     }
#
#
#
# <b>18.</b> State the values that the six fprintf statements will print. Assume the following addresses: (Writing the last three hex digits is sufficient for full credit)
#
# Address of register a is   : <code>0x7ffc09bc1990</code>
#
# Address of register b is   : <code>0x7ffc09bc1994</code>
#
# Address of register a_pf is: <code>0x7ffc09bc197c</code>
#
# Address of register b_pf is: <code>0x7ffc09bc1970</code>
#
# </b>
#
#     #include <stdio.h>
#
#     void pointer_func(int a_pf, int* b_pf ){
#
#         a_pf = 27;
#         *b_pf = 11;
#
#         fprintf( stdout, "%x %p\n", a_pf, &a_pf);
#
#         fprintf( stdout, "%d %p %p\n", *b_pf, b_pf, &b_pf);
#
#     }
#
#     int main(){
#
#         int a = 10;
#         int b = 20;
#
#         fprintf( stdout, "%d %p\n", a, &a);
#
#         fprintf( stdout, "%x %p\n", b, &b);
#
#         pointer_func( a, &b );
#
#         fprintf( stdout, "%d %p\n", a, &a);
#
#         fprintf( stdout, "%x %p\n", b, &b);
#
#         return 0;
#     }
#
# <b>19.</b> Given the following code segment, write the expected output of the fprintf statements. Assume the following addresses: (Writing the last three hex digits is sufficient for full credit)</b>
#
# <b>Base address of <code>the_array</code></b> - <code>0x7fff483759b0</code><br>
# <b>Address of <code>array_len</code></b> - <code>0x7fff483759a8</code><br>
# <b>Address of <code>array_len_pf</code></b> - <code>0x7fff483759e0</code><br>
#
#
#     #include <stdio.h>
#
#     void print_func(int the_array_pf[], long unsigned int* array_len_pf ){
#
#         fprintf( stdout, "%p %lu %p %p\n", the_array_pf, *array_len_pf, array_len_pf, &array_len_pf);
#
#         long unsigned int iter;
#         for( iter = 0; iter < *array_len_pf; ++iter ){
#
#             fprintf( stdout, "%lu %d %p\n", iter, the_array_pf[iter], &the_array_pf[iter] );
#         }
#
#     }
#
#     int main(){
#
#         int the_array[] = {10, 22, 17, -5, 31};
#
#         long unsigned int array_len = 5;
#
#         fprintf( stdout, "%p %lu %p\n", the_array, array_len, &array_len);
#
#         print_func( the_array, &array_len );
#
#         return 0;
#     }
