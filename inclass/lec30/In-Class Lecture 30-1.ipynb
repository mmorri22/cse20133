# %% [markdown]
# ## In-Class Lecture 30-1 - Big-O Notation Example Problems

# %% [markdown]
# ### “An engineer will do for a dime what any fool will do for a dollar”
#
# #### Efficiency comes in two flavors:
#
# <b>Programming cost</b>:
# <ul>
#     <li>How long does it take to develop your programs?</li>
#     <li>How easy is it to read, modify, and maintain your code?</li>
#     <li>More important than you might think!</li>
#     <li>Majority of cost is in maintenance, not development!</li>
# </ul>
#
# <b>Execution cost </b>:
# <ul>
#     <li>How much time does your program take to execute?</li>
#     <li>How much memory does your program require?</li>
# </ul>

# %% [markdown]
# ### Problem 1
#
# Given the following code segment, derive and state the runtime in Big-O notation, as well as the informal description.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Problem 2
#
# Given the following code segment, derive and state the runtime in Big-O notation
#
#     for( iter = 0; iter < loop_one ; ++iter ){
#         while( m > 0 ){
#             for( jter = 0; jter < loop_two ; ++jter ){
#                k += array[iter][jter];
#             }
#             m /= 2;
#          }
#     }

# %% [markdown]
# ## Problem 3
#
# Take 5 minutes and work with a classmate
#
# Given the following code segment, determine and state the runtime in Big-O notation, as well as the informal description.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Problem 4
#
# Given the following code segment, derive and state the runtime in Big-O notation.
#
#     while( q > 0 ){
#         q /= 3;
#     }
#
#     for( iter = 0; iter < the_loop ; ++iter ){
#         k += array[iter]
#     }

# %% [markdown]
# ## Problem 5
#
# Given the following code segment, select the correct description of the runtime in Big-O notation.
#
#     for( iter = 0; iter < 3*max_len; ++iter ){
#
#         for( jter = 0; jter < 4 * max_len; ++jter) {
#             k += array[iter][jter];
#         }
#
#         for( kter = 0; kter < 5 * max_len; ++kter) {
#             while ( q > 0 )
#                 q /= 2;
#         }
#
#     }

# %% [markdown]
# ## Problem 6
#
# Work together as a group to solve this provlem
#
# Given the following code segment, select the correct description of the runtime in Big-O notation.
#
#     for( iter = 0; iter < 3*max_len; ++iter ){
#
#         for( jter = 0; jter < 4 * max_len; ++jter) {
#             k += array[iter][jter];
#
#             for( kter = 0; kter < 5 * max_len; ++kter) {
#                 while ( q > 0 )
#                     q /= 2;
#             }
#
#         }
#
#     }
