# %% [markdown]
# ## In-Class Lecture 11-1 - Building and Iterating Through Arrays

# %% [markdown]
# ### Reviewing Opening your Environment on the Notre Dame Machines
#
# <b>1.</b> Log into the Notre Dame Machines as you performed on Homework 1 using Tabby Terminal
#
# Open Tabby Terminal on your machine.
#
# Type in: <code>ssh -Y username@student13.cse.nd.edu</code>
# <ul><li>"username" is your NetID.</li>
# <ul>
# <li>Example: my email is matt.morrison@nd.edu, but my NetID is mmorri22, so I would enter:<p>
# <code>ssh -Y mmorri22@student13.cse.nd.edu</code><p>
# The <code>-Y</code> is included to treat the Notre Dame machines as a trusted client<p>
# </li>
# </ul>
# </ul>
#
# 2. Next, we will create a directory where you will save your Reading Code. First, we will go into the Dropbox directory where you will submit your code:
#
# <code>cd esc-courses</code>
#
# <code>cd fa26-cse-20133.01</code>
#
# <code>cd dropbox</code>
#
# Make a directory for you to practice your code for this lecture
#
#     mkdir inclass11
#     cd inclass11
#
# Enable script so you can run the most up-to-date versions of C and C++:
#
#     scl enable gcc-toolset-15 bash
#
# > <b>Note:</b> If you use the <code>-std=c2x</code> and get the following error, this means you did not run the enable command<br>
# > <code>gcc: error: unrecognized command line option ‘-std=c2x’; did you mean ‘-std=c1x’?</code>

# %% [markdown]
# ### To setup for today's in-class coding opportunity:
#
# To obtain the code for today's lecture, perform the following commands:
#
#     wget https://raw.githubusercontent.com/mmorri22/cse20133/main/inclass/lec11/setup.sh
#     chmod a+rx setup.sh
#     ./setup.sh
#
# To confirm, perform the <code>ls</code> command. You will see the following:
#
#     fscanf.c  Makefile  static_basic.c  static_pbr.c

# %% [markdown]
# ### Reading Discussion Questions
#
# #### <font color = "red">Class Introduction Question #1 - What are the three defining characteristics of an array?</font>
#
# #### <font color = "red">Class Introduction Question #2 - How do we create a static array in C? Where are static arrays stored in the computer?</a>

# %% [markdown]
# ### Basic Arrays
#
# We will work together to create a file <code>static_basic.c</code> where we will initialize an integer array with six elements, and then we will iterate through the array, printing out the value and its location at each stage.
#
# We will also learn about compiler directives
#
#     #ARRAYSIZE 6
#
# The Makefile will contain a <code>make static_basic</code> command with a <b>deliberate error</b>. We will find it together.
#
#     make static_basic
#
# We will draw a memory map, where we correlate the memory locations printed to our Thinking Model

# %% [markdown]
# ### Reading Discussion Questions
#
# #### <font color = "red">Class Introduction Question #3 - Why are static array passed by reference in C</font>
#
# #### <font color = "red">Class Introduction Question #4 - What happens when we make changes to values in a static array passed by reference to a function in C?</font>

# %% [markdown]
# ### Pass by Reference
#
# We will work together to pass the array by reference, along with the array size, in order to increment each element in the array by a specified number. We will also update the sum while iterating through the array, where the sum register is in main. We will also print the results in a third function.
#
#     cp static_basic.c static_pbr.c
#
# Then we will pass the array to a function and perform the same task
#
#     make static_pbr
#
# We will also build up a memory map of the static array
