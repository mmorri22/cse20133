# %% [markdown]
# ## In-Class Lecture 7-1 - Functions
#
# In this section, we will create functions that takes in the variables we created in other files, and then promotes <b>modularity</b> and <b>information</b> hiding.

# %% [markdown]
# ### Reviewing Opening your Environment on the Notre Dame Machines
#
# <b>1.</b> Log into the Notre Dame Machines as you performed on Homework 1 using Tabby Terminal
#
# Open Tabby Terminal on your machine.
#
# Type in: <code>ssh -Y username@student13.cse.nd.edu</code>
# <ul><li>"username" is your NetID.</li>
# <ul>
# <li>Example: my email is matt.morrison@nd.edu, but my NetID is mmorri22, so I would enter:<p>
# <code>ssh -Y mmorri22@student13.cse.nd.edu</code><p>
# The <code>-Y</code> is included to treat the Notre Dame machines as a trusted client<p>
# </li>
# </ul>
# </ul>
#
# 2. Next, we will create a directory where you will save your Reading Code. First, we will go into the Dropbox directory where you will submit your code:
#
# <code>cd esc-courses</code>
#
# <code>cd fa26-cse-20133.01</code>
#
# <code>cd dropbox</code>
#
# Make a directory for you to practice your code for this lecture
#
#     mkdir inclass07
#     cd inclass07
#
# Enable script so you can run the most up-to-date versions of C and C++:
#
#     scl enable gcc-toolset-15 bash
#
# > <b>Note:</b> If you use the <code>-std=c2x</code> and get the following error, this means you did not run the enable command<br>
# > <code>gcc: error: unrecognized command line option ‘-std=c2x’; did you mean ‘-std=c1x’?</code>

# %% [markdown]
# In your <code>inclass07</code> folder, obtain the <code>functions.c</code> skeleton code:
#
#     wget https://raw.githubusercontent.com/mmorri22/cse20133/main/inclass/lec07/functions.c

# %% [markdown]
# ## Function Declarations
#
# We will first create a function that takes in the if-else variables and then print the result
#
# For the function declarations, we will perform the following task <i>above</i> main:
#
#     return-type function_name( input_variables );
#
#
# For the function definitions, we will perform the following task <i>below</i> main:
#
#     return-type function_name( input_variables ){
#
#         Copied code from if-else main goes here
#
#     }
#
# Then, we will create a <b>Function Header</b> above the if_else function with this format:
#
#     /********************************************
#      * Function Name: function_name
#      * Pre-Conditions: input_variables
#      * Post-Conditions: return-type
#      *
#      * Brief Description of what the code does
#      *******************************************/

# %% [markdown]
# #### Compilation
#
# We will regularly test and compile the code
#
#     gcc -Wall -Wextra -std=c2x -Wconversion -Werror functions.c -o functions
#     ./functions
#     rm functions

# %% [markdown]
# ## Repeat with while / for
#
# Pair and Share
#
# There will be three pairs who will get opportunities:
# <ul>
#     <li>Copy <code>while.c</code> from <code>inclass06</code> to <code>while_func.c</code> in <code>inclass07</code> and pass the inputs to a function. Run the while loop in that function</li>
#     <li>Copy <code>for.c</code> from <code>inclass06</code> to <code>for_func.c</code> in <code>inclass07</code> and pass the inputs to a function. Run the for loop in that function</li>
# </ul>
#
# For the <code>while_func.c</code>:
#
#     gcc -Wall -Wextra -std=c2x -Wconversion -Werror while_func.c -o while_func
#     ./while_func
#     rm while_func
#
# For the <code>dowhile_func.c</code>:
#
#     gcc -Wall -Wextra -std=c2x -Wconversion -Werror dowhile_func.c -o dowhile_func
#     ./dowhile_func
#     rm dowhile_func
#
# For the <code>for_func.c</code>:
#
#     gcc -Wall -Wextra -std=c2x -Wconversion -Werror for_func.c -o for_func
#     ./for_func
#     rm for_func
