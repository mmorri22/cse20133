# %% [markdown]
# ## In-Class Lecture 7-1 - Repetitive Statements
#
# In this section, we will learn to differentiate between if, else if, and switch statements

# %% [markdown]
# ### Reviewing Opening your Environment on the Notre Dame Machines
#
# <b>1.</b> Log into the Notre Dame Machines as you performed on Homework 1 using Tabby Terminal
#
# Open Tabby Terminal on your machine.
#
# Type in: <code>ssh -Y username@student13.cse.nd.edu</code>
# <ul><li>"username" is your NetID.</li>
# <ul>
# <li>Example: my email is matt.morrison@nd.edu, but my NetID is mmorri22, so I would enter:<p>
# <code>ssh -Y mmorri22@student13.cse.nd.edu</code><p>
# The <code>-Y</code> is included to treat the Notre Dame machines as a trusted client<p>
# </li>
# </ul>
# </ul>
#
# 2. Next, we will create a directory where you will save your Reading Code. First, we will go into the Dropbox directory where you will submit your code:
#
# <code>cd esc-courses</code>
#
# <code>cd fa26-cse-20133.01</code>
#
# <code>cd dropbox</code>
#
# Make a directory for you to practice your code for this lecture
#
#     mkdir inclass07
#     cd inclass07
#
# Enable script so you can run the most up-to-date versions of C and C++:
#
#     scl enable gcc-toolset-15 bash
#
# > <b>Note:</b> If you use the <code>-std=c2x</code> and get the following error, this means you did not run the enable command<br>
# > <code>gcc: error: unrecognized command line option ‘-std=c2x’; did you mean ‘-std=c1x’?</code>

# %% [markdown]
# ## For Loop
# In your <code>inclass07</code> folder, obtain the <code>for.c</code> skeleton code
#
#     wget https://raw.githubusercontent.com/mmorri22/cse20133/main/inclass/lec07/for.c
#
# Pair and Share
#
# With a partner, build a <code>for</code> loop based on a research topic of a student's choice.
#
# The compilation, execution, and deletion commands for this part are:
#
#     gcc -Wall -std=c2x -Wconversion -Werror for.c -o for
#     ./for
#     rm for

# %% [markdown]
# ## Data Types and Looping
#
# We will discuss a unique case in loop: <b>What happens when the data produces undesired behavior?</b>
#
# In your <code>inclass07</code> folder, obtain the <code>for.c</code> skeleton code
#
#     wget https://raw.githubusercontent.com/mmorri22/cse20133/main/inclass/lec07/lui_while.c
#
# What do we think will happen?
#
#     gcc -Wall -std=c2x -Wconversion -Werror lui_while.c -o lui_while
#
# > To stop the loop, press <code>Ctrl-C</code> or <code>Command-C</code>
#
# It turns out that <code>-Wall</code> for <i>all warnings</i> doesn't actually cover all the warnings. <code>-Wall</code> only covers up to 1999 for C.
#
# We will now introduce our next compiler flag: <code>-Wextra</code>
#
#     gcc -Wall -Wextra -std=c2x -Wconversion -Werror lui_while.c -o lui_while
#
# And we now see that we have added protections for our code.
