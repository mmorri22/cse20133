# %% [markdown]
# ## In-Class Lecture 33-3 - <code>pthread</code> Memory Draw Problem

# %% [markdown]
# Given the code in <code>pthread_in_class.cpp</code> and the memory addresses below, draw the final memory layout:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Problem Notes:
#
# The pthreads are not in sorted order, and I will not sort them on the Exam
#
#     Purpose: To make you think (build neuron links) about parallelism
#
# > Did you see how, when you sorted the pthreads, the structuring of the Data became clear?

# %% [markdown]
# ## Example Solution
#
# Here is the example solution. I will run the code again, and you will see that there is a different ordering.
#
# > As I have done in the past, I will copy the output and post to the course page.
#
# ![image.png](attachment:image.png)
